# %%
import pandas as pd

# %%
df = pd.read_csv("../Analysis Data/earthquake_data.csv")
df
# Out:
#      In general, how worried are you about earthquakes?  \
# 0                                    Not at all worried
# 1                                      Somewhat worried
# 2                                        Not so worried
# 3                                        Not so worried
# 4                                        Not so worried
# ...                                                 ...
# 1008                                 Not at all worried
# 1009                                     Not so worried
# 1010                                     Not so worried
# 1011                                 Not at all worried
# 1012                                   Somewhat worried
#
#      How worried are you about the Big One, a massive, catastrophic earthquake?  \
# 0                                        Not so worried
# 1                                          Very worried
# 2                                      Somewhat worried
# ...

# %%
df_sorted = df[["Age", "What is your gender?", 'Do you think the "Big One" will occur in your lifetime?']]
df_sorted = df_sorted.rename(columns={"What is your gender?": "Gender", 'Do you think the "Big One" will occur in your lifetime?': "Big One"})
df_sorted = df_sorted.sort_values(["Age"])
df_sorted.to_csv(path_or_buf="../Analysis Data/earthquake_data_changed.csv", index=False)

# %%
df_sorted = pd.read_csv("../Analysis Data/earthquake_data_changed.csv")
df_sorted
# Out:
#           Age  Gender Big One
# 0     18 - 29    Male      No
# 1     18 - 29  Female     Yes
# 2     18 - 29  Female      No
# 3     18 - 29  Female      No
# 4     18 - 29  Female      No
# ...       ...     ...     ...
# 1008      NaN     NaN      No
# 1009      NaN     NaN     Yes
# 1010      NaN     NaN     Yes
# 1011      NaN     NaN      No
# 1012      NaN     NaN      No
#
# [1013 rows x 3 columns]
